# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Shyam\\Desktop\\renal_tumor_classification_project'

# %%
os.environ["MLFLOW_TRACKING_URL"]="https://dagshub.com/Shyamanth-2005/renal_tumor_classification.mlflow/"
os.environ["MLFLOW_TRACKING_USERNAME"]="Shyamanth-2005"
os.environ["MLFLOW_TRACKING_PASSWORD"]="1d22cf43202806cbe2bce95333b79a30fa13b1cb"

# %%
MLFLOW_TRACKING_URL=https://dagshub.com/Shyamanth-2005/renal_tumor_classification.mlflow/
MLFLOW_TRACKING_USERNAME=Shyamanth-2005 \
MLFLOW_TRACKING_PASSWORD=1d22cf43202806cbe2bce95333b79a30fa13b1cb \
python script.py
